# %% [markdown]
# Import

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import optuna

# %% [markdown]
# Creation de l'environnement

# %%
environment_name = 'CarRacing-v0'
env = gym.make(environment_name)
env.seed(42)
print('Action space :', env.action_space, '||| Observation space (shape) :', env.observation_space.shape)
# Out:
# Action space : Box([-1.  0.  0.], [1. 1. 1.], (3,), float32) ||| Observation space (shape) : (96, 96, 3)

# %% [markdown]
# 1er test avec un agent aléatoire

# %%
episodes = 2
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print(f'Episode:{episode} Score:{score}')
env.close()
# Out:
# Track generation: 1208..1514 -> 306-tiles track
# Episode:1 Score:-34.42622950819724
# Track generation: 1203..1508 -> 305-tiles track
# Episode:2 Score:-34.2105263157899

# %% [markdown]
# ### Creation de notre 1er model de test :

# %% [markdown]
# Creation de notre environnement DummyVecEnv à entrainer
#
# Avec ajout de `env.seed(42)` afin de garder les memes parcours

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
env.seed(42)
# Out:
# [[42]]

# %% [markdown]
# Declaration du model de PPO avec stable baseline

# %%
model = PPO("CnnPolicy", env, verbose=1, device='mps')
# Out:
# Using mps device
# Wrapping the env in a VecTransposeImage.

# %%
timesteps = 200000
model.learn(total_timesteps=timesteps)
# Out:
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 134  |
# |    iterations      | 1    |
# |    time_elapsed    | 15   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1129..1416 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 2           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010080028 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.00309    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.178       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00748    |
# |    std                  | 1           |
# |    value_loss           | 0.568       |
# -----------------------------------------
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1048..1318 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1236..1549 -> 313-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 3           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009987505 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0718      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.186       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.999       |
# |    value_loss           | 0.475       |
# -----------------------------------------
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 4           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013473087 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0728      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.991       |
# |    value_loss           | 0.463       |
# -----------------------------------------
# Track generation: 1157..1451 -> 294-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 5           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017420625 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.0825      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0709      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.978       |
# |    value_loss           | 0.406       |
# -----------------------------------------
# Track generation: 1037..1307 -> 270-tiles track
# Track generation: 1011..1271 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 6           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015262445 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0476      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.974       |
# |    value_loss           | 0.427       |
# -----------------------------------------
# Track generation: 1059..1328 -> 269-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 7           |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016192738 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0257      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0265     |
# |    std                  | 0.963       |
# |    value_loss           | 0.359       |
# -----------------------------------------
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1355..1697 -> 342-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 8           |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.024342114 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0588      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.949       |
# |    value_loss           | 0.282       |
# -----------------------------------------
# Track generation: 1131..1421 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 9           |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018383253 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0646      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 0.944       |
# |    value_loss           | 0.325       |
# -----------------------------------------
# Track generation: 1130..1417 -> 287-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 10          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.030279342 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0537      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0336     |
# |    std                  | 0.933       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 11         |
# |    time_elapsed         | 227        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.03842476 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.03      |
# |    explained_variance   | 0.659      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0156    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0431    |
# |    std                  | 0.923      |
# |    value_loss           | 0.221      |
# ----------------------------------------
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 12          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.036365215 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0123      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 0.911       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1071..1352 -> 281-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 13          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.039486658 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0025      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0448     |
# |    std                  | 0.896       |
# |    value_loss           | 0.242       |
# -----------------------------------------
# Track generation: 1042..1311 -> 269-tiles track
# Track generation: 1401..1755 -> 354-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 14          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.044542745 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000454    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.05       |
# |    std                  | 0.885       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1270..1592 -> 322-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 15         |
# |    time_elapsed         | 312        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03635748 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.88      |
# |    explained_variance   | 0.73       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0473    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0476    |
# |    std                  | 0.88       |
# |    value_loss           | 0.205      |
# ----------------------------------------
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 16          |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.042062253 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0518     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0491     |
# |    std                  | 0.866       |
# |    value_loss           | 0.165       |
# -----------------------------------------
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1129..1424 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 17          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.049530983 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0415     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0496     |
# |    std                  | 0.85        |
# |    value_loss           | 0.169       |
# -----------------------------------------
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 18          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.044208728 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0284     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0426     |
# |    std                  | 0.847       |
# |    value_loss           | 0.19        |
# -----------------------------------------
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1030..1295 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1118..1401 -> 283-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 19          |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.056051325 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0631     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0575     |
# |    std                  | 0.841       |
# |    value_loss           | 0.123       |
# -----------------------------------------
# Track generation: 1313..1645 -> 332-tiles track
# Track generation: 1193..1494 -> 301-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 20         |
# |    time_elapsed         | 416        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.04141772 |
# |    clip_fraction        | 0.341      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.69      |
# |    explained_variance   | 0.719      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0386    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0454    |
# |    std                  | 0.825      |
# |    value_loss           | 0.318      |
# ----------------------------------------
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1034..1301 -> 267-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 21         |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.05978281 |
# |    clip_fraction        | 0.376      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.64      |
# |    explained_variance   | 0.743      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0286    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0534    |
# |    std                  | 0.813      |
# |    value_loss           | 0.164      |
# ----------------------------------------
# Track generation: 1003..1266 -> 263-tiles track
# Track generation: 1219..1534 -> 315-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 22          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.071025774 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0368     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0546     |
# |    std                  | 0.803       |
# |    value_loss           | 0.232       |
# -----------------------------------------
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1004..1261 -> 257-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1253..1570 -> 317-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 23         |
# |    time_elapsed         | 479        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.07301019 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.65       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00345   |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0466    |
# |    std                  | 0.797      |
# |    value_loss           | 0.548      |
# ----------------------------------------
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 24          |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.067532495 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0303     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0475     |
# |    std                  | 0.789       |
# |    value_loss           | 0.357       |
# -----------------------------------------
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 25         |
# |    time_elapsed         | 523        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.07251029 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.5       |
# |    explained_variance   | 0.814      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.012      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0503    |
# |    std                  | 0.776      |
# |    value_loss           | 0.417      |
# ----------------------------------------
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 26         |
# |    time_elapsed         | 544        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.09113084 |
# |    clip_fraction        | 0.424      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.45      |
# |    explained_variance   | 0.803      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0419    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0533    |
# |    std                  | 0.767      |
# |    value_loss           | 0.287      |
# ----------------------------------------
# Track generation: 1303..1633 -> 330-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 27          |
# |    time_elapsed         | 565         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.056248855 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0428      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0476     |
# |    std                  | 0.753       |
# |    value_loss           | 0.466       |
# -----------------------------------------
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 28         |
# |    time_elapsed         | 586        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.13762644 |
# |    clip_fraction        | 0.493      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.36      |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0656    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0605    |
# |    std                  | 0.74       |
# |    value_loss           | 0.224      |
# ----------------------------------------
# Track generation: 1167..1473 -> 306-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 29         |
# |    time_elapsed         | 608        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.11993892 |
# |    clip_fraction        | 0.48       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | 0.816      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0699    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0563    |
# |    std                  | 0.726      |
# |    value_loss           | 0.251      |
# ----------------------------------------
# Track generation: 1093..1371 -> 278-tiles track
# Track generation: 1372..1719 -> 347-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 30         |
# |    time_elapsed         | 629        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.09584896 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.25      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0253     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0571    |
# |    std                  | 0.719      |
# |    value_loss           | 0.339      |
# ----------------------------------------
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 31         |
# |    time_elapsed         | 650        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.10932732 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0432    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0604    |
# |    std                  | 0.703      |
# |    value_loss           | 0.33       |
# ----------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1205..1518 -> 313-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 32          |
# |    time_elapsed         | 672         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.090468206 |
# |    clip_fraction        | 0.454       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0526      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.048      |
# |    std                  | 0.694       |
# |    value_loss           | 0.488       |
# -----------------------------------------
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1325..1660 -> 335-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 33         |
# |    time_elapsed         | 693        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.08487671 |
# |    clip_fraction        | 0.45       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0246    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0524    |
# |    std                  | 0.688      |
# |    value_loss           | 0.706      |
# ----------------------------------------
# Track generation: 1285..1611 -> 326-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 34         |
# |    time_elapsed         | 713        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.11907907 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0445     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0466    |
# |    std                  | 0.684      |
# |    value_loss           | 0.829      |
# ----------------------------------------
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 35          |
# |    time_elapsed         | 735         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.113206826 |
# |    clip_fraction        | 0.486       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000622   |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0497     |
# |    std                  | 0.678       |
# |    value_loss           | 0.522       |
# -----------------------------------------
# Track generation: 1103..1389 -> 286-tiles track
# Track generation: 1146..1435 -> 289-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 36         |
# |    time_elapsed         | 756        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.17543724 |
# |    clip_fraction        | 0.483      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.026     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0395    |
# |    std                  | 0.667      |
# |    value_loss           | 0.3        |
# ----------------------------------------
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 37         |
# |    time_elapsed         | 777        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.08689769 |
# |    clip_fraction        | 0.448      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00729   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0402    |
# |    std                  | 0.661      |
# |    value_loss           | 0.741      |
# ----------------------------------------
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1011..1273 -> 262-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 38          |
# |    time_elapsed         | 798         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.060692564 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.156       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.036      |
# |    std                  | 0.653       |
# |    value_loss           | 1.33        |
# -----------------------------------------
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1154..1449 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1165..1460 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 39         |
# |    time_elapsed         | 819        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.11048749 |
# |    clip_fraction        | 0.491      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0133    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0448    |
# |    std                  | 0.647      |
# |    value_loss           | 0.466      |
# ----------------------------------------
# Track generation: 1269..1597 -> 328-tiles track
# Track generation: 995..1248 -> 253-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 40          |
# |    time_elapsed         | 840         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.082929745 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0299     |
# |    std                  | 0.643       |
# |    value_loss           | 0.775       |
# -----------------------------------------
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 41        |
# |    time_elapsed         | 861       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.0659356 |
# |    clip_fraction        | 0.422     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.88     |
# |    explained_variance   | 0.889     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.153     |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.0247   |
# |    std                  | 0.637     |
# |    value_loss           | 1.74      |
# ---------------------------------------
# Track generation: 1232..1552 -> 320-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 42         |
# |    time_elapsed         | 883        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.11669522 |
# |    clip_fraction        | 0.478      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.87      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.116      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0324    |
# |    std                  | 0.638      |
# |    value_loss           | 0.952      |
# ----------------------------------------
# Track generation: 978..1232 -> 254-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 43          |
# |    time_elapsed         | 904         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.120821945 |
# |    clip_fraction        | 0.465       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.038      |
# |    std                  | 0.631       |
# |    value_loss           | 0.392       |
# -----------------------------------------
# Track generation: 1185..1485 -> 300-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 44         |
# |    time_elapsed         | 925        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.07907724 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.14       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0256    |
# |    std                  | 0.626      |
# |    value_loss           | 1.13       |
# ----------------------------------------
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 45          |
# |    time_elapsed         | 946         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.056368746 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.776       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.625       |
# |    value_loss           | 2.99        |
# -----------------------------------------
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 963..1208 -> 245-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 46          |
# |    time_elapsed         | 969         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.087314904 |
# |    clip_fraction        | 0.455       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0564      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.622       |
# |    value_loss           | 1.11        |
# -----------------------------------------
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 47        |
# |    time_elapsed         | 990       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.1006121 |
# |    clip_fraction        | 0.434     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.79     |
# |    explained_variance   | 0.963     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.191     |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.0214   |
# |    std                  | 0.621     |
# |    value_loss           | 1.49      |
# ---------------------------------------
# Track generation: 1400..1754 -> 354-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 48         |
# |    time_elapsed         | 1012       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.08758346 |
# |    clip_fraction        | 0.479      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.78      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.822      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00885   |
# |    std                  | 0.622      |
# |    value_loss           | 5.57       |
# ----------------------------------------
# Track generation: 994..1254 -> 260-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 49         |
# |    time_elapsed         | 1034       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.09552048 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.78      |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00642   |
# |    std                  | 0.621      |
# |    value_loss           | 7.83       |
# ----------------------------------------
# Track generation: 1127..1414 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 50         |
# |    time_elapsed         | 1055       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.17851311 |
# |    clip_fraction        | 0.543      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.78      |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.84       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00372   |
# |    std                  | 0.621      |
# |    value_loss           | 4.85       |
# ----------------------------------------
# Track generation: 1242..1556 -> 314-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 51       |
# |    time_elapsed         | 1076     |
# |    total_timesteps      | 104448   |
# | train/                  |          |
# |    approx_kl            | 0.13273  |
# |    clip_fraction        | 0.541    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.78    |
# |    explained_variance   | 0.91     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.596    |
# |    n_updates            | 500      |
# |    policy_gradient_loss | -0.0104  |
# |    std                  | 0.619    |
# |    value_loss           | 8.53     |
# --------------------------------------
# Track generation: 1138..1435 -> 297-tiles track
# Track generation: 1089..1371 -> 282-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 52         |
# |    time_elapsed         | 1097       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.18608828 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.77      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.296      |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00242   |
# |    std                  | 0.619      |
# |    value_loss           | 3.82       |
# ----------------------------------------
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1092..1371 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1183..1483 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 53         |
# |    time_elapsed         | 1117       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.23414607 |
# |    clip_fraction        | 0.548      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.76      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.282      |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00805   |
# |    std                  | 0.614      |
# |    value_loss           | 1.88       |
# ----------------------------------------
# Track generation: 1096..1374 -> 278-tiles track
# Track generation: 1157..1450 -> 293-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 54          |
# |    time_elapsed         | 1138        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.124273926 |
# |    clip_fraction        | 0.492       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.957       |
# ...
# Track generation: 1267..1596 -> 329-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 81          |
# |    time_elapsed         | 1726        |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.062027756 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.599       |
# |    value_loss           | 1.71        |
# -----------------------------------------
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 82          |
# |    time_elapsed         | 1747        |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.044567067 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.422       |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00373    |
# |    std                  | 0.595       |
# |    value_loss           | 2.87        |
# -----------------------------------------
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1090..1372 -> 282-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 83         |
# |    time_elapsed         | 1769       |
# |    total_timesteps      | 169984     |
# | train/                  |            |
# |    approx_kl            | 0.11463055 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.61      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.117      |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0157    |
# |    std                  | 0.587      |
# |    value_loss           | 1.51       |
# ----------------------------------------
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1052..1324 -> 272-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 84          |
# |    time_elapsed         | 1792        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.060877495 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.24        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.582       |
# |    value_loss           | 1.53        |
# -----------------------------------------
# Track generation: 1109..1390 -> 281-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 85         |
# |    time_elapsed         | 1814       |
# |    total_timesteps      | 174080     |
# | train/                  |            |
# |    approx_kl            | 0.07122852 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.55      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.207      |
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.0154    |
# |    std                  | 0.58       |
# |    value_loss           | 1.65       |
# ----------------------------------------
# Track generation: 1058..1327 -> 269-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 86          |
# |    time_elapsed         | 1836        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.066162914 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.543       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.577       |
# |    value_loss           | 1.67        |
# -----------------------------------------
# Track generation: 1169..1465 -> 296-tiles track
# Track generation: 1091..1376 -> 285-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 87         |
# |    time_elapsed         | 1858       |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.08881208 |
# |    clip_fraction        | 0.47       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.52      |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.386      |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.00596   |
# |    std                  | 0.573      |
# |    value_loss           | 3.29       |
# ----------------------------------------
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1075..1347 -> 272-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 88         |
# |    time_elapsed         | 1879       |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.07603055 |
# |    clip_fraction        | 0.482      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.5       |
# |    explained_variance   | 0.577      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.669      |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0111    |
# |    std                  | 0.572      |
# |    value_loss           | 5.9        |
# ----------------------------------------
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1032..1294 -> 262-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 89         |
# |    time_elapsed         | 1899       |
# |    total_timesteps      | 182272     |
# | train/                  |            |
# |    approx_kl            | 0.17204049 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.49      |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.374      |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.00256   |
# |    std                  | 0.569      |
# |    value_loss           | 4.77       |
# ----------------------------------------
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 90         |
# |    time_elapsed         | 1920       |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.11173159 |
# |    clip_fraction        | 0.477      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.48      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.429      |
# |    n_updates            | 890        |
# |    policy_gradient_loss | 0.00236    |
# |    std                  | 0.567      |
# |    value_loss           | 5.72       |
# ----------------------------------------
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 91         |
# |    time_elapsed         | 1940       |
# |    total_timesteps      | 186368     |
# | train/                  |            |
# |    approx_kl            | 0.30917412 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.47      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.79       |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.00232   |
# |    std                  | 0.566      |
# |    value_loss           | 6.62       |
# ----------------------------------------
# Track generation: 1279..1603 -> 324-tiles track
# Track generation: 1009..1268 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1111..1393 -> 282-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 92         |
# |    time_elapsed         | 1962       |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.41533023 |
# |    clip_fraction        | 0.518      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.77       |
# |    n_updates            | 910        |
# |    policy_gradient_loss | 0.0152     |
# |    std                  | 0.564      |
# |    value_loss           | 6.56       |
# ----------------------------------------
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1114..1402 -> 288-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 93         |
# |    time_elapsed         | 1986       |
# |    total_timesteps      | 190464     |
# | train/                  |            |
# |    approx_kl            | 0.09486882 |
# |    clip_fraction        | 0.508      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.744      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.14       |
# |    n_updates            | 920        |
# |    policy_gradient_loss | 0.00716    |
# |    std                  | 0.564      |
# |    value_loss           | 8.64       |
# ----------------------------------------
# Track generation: 1031..1293 -> 262-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 94         |
# |    time_elapsed         | 2007       |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.15638173 |
# |    clip_fraction        | 0.578      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.61       |
# |    n_updates            | 930        |
# |    policy_gradient_loss | 0.0131     |
# |    std                  | 0.565      |
# |    value_loss           | 8.58       |
# ----------------------------------------
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1082..1356 -> 274-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 95         |
# |    time_elapsed         | 2027       |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.15375683 |
# |    clip_fraction        | 0.577      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.402      |
# |    n_updates            | 940        |
# |    policy_gradient_loss | 0.00275    |
# |    std                  | 0.564      |
# |    value_loss           | 7.88       |
# ----------------------------------------
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1126..1412 -> 286-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 96         |
# |    time_elapsed         | 2048       |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.73824877 |
# |    clip_fraction        | 0.659      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.864      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.535      |
# |    n_updates            | 950        |
# |    policy_gradient_loss | 0.0313     |
# |    std                  | 0.565      |
# |    value_loss           | 13.8       |
# ----------------------------------------
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 97         |
# |    time_elapsed         | 2069       |
# |    total_timesteps      | 198656     |
# | train/                  |            |
# |    approx_kl            | 0.14301571 |
# |    clip_fraction        | 0.603      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.907      |
# |    n_updates            | 960        |
# |    policy_gradient_loss | 0.0178     |
# |    std                  | 0.567      |
# |    value_loss           | 11.5       |
# ----------------------------------------
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 988..1239 -> 251-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 98         |
# |    time_elapsed         | 2090       |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.09579134 |
# |    clip_fraction        | 0.527      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.445      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.798      |
# |    n_updates            | 970        |
# |    policy_gradient_loss | 0.0176     |
# |    std                  | 0.568      |
# |    value_loss           | 6.53       |
# ----------------------------------------

# %% [markdown]
# On sauvegarde notre model avec son timestep et ses particularités

# %%
model_path = f'models/PPO_200k_base_seed42__model'
model.save(model_path)

# %% [markdown]
# On charge le model (si on veut selectionner le meilleur par exemple)

# %%
load_model_path = f'models/PPO_200k_base_seed42__model'
model = PPO.load(load_model_path, env=env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# On evalue le model avec 2 mesures :
#  - La récompense moyenne
#  - L'écart type
#
# Une *récompense moyenne élevée* et un *écart type faible* sont signe d'une politique **performante et stable**
#
# Tandis qu'une politique qui obtient une *récompense moyenne faible* et un *écart type élevé* est considérée comme **peu performante et instable**.

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, render=True)
# Out:
# Track generation: 899..1133 -> 234-tiles track
# /Users/robinfournier/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1039..1305 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1229..1546 -> 317-tiles track

# %%
print('Récompense moyenne :', mean_reward, '||| Écart type :', std_reward)
# Out:
# Récompense moyenne : 569.3619286179543 ||| Écart type : 269.2836495382977

# %% [markdown]
# ## Optuna

# %% [markdown]
# Recherche d'optimisation des parametres avec Optuna :
#
# (Derniere MAJ qui garde aussi un environnement similaire avec `env.seed(42)`)

# %%
study_name = "study_200k_seed42"
timesteps = 200000

# %%
def objective(trial):

    # Define hyperparameters
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2)
    gamma = trial.suggest_float('gamma', 0.9, 0.99)
    clip_range = trial.suggest_float('clip_range', 0.1, 0.4)
    ent_coef = trial.suggest_float('ent_coef', 1e-4, 1e-3)

    environment_name = 'CarRacing-v0'
    env = gym.make(environment_name)
    env = DummyVecEnv([lambda: env])
    env.seed(42)

    model = PPO("CnnPolicy", env, verbose=0, 
                learning_rate=learning_rate, gamma=gamma,
                clip_range=clip_range, ent_coef=ent_coef, device="mps")

    # Train model
    model.learn(total_timesteps=timesteps)

    # Save model
    model_path = f'models/{study_name}/PPO_{learning_rate}_{gamma}__{clip_range}_{ent_coef}__model'
    model.save(model_path)

    # Load model
    model = PPO.load(model_path, env=env)

    # Evaluate model
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5)

    # Close environment
    env.close()

    # Return mean reward to maximize
    return mean_reward

# %%
study = optuna.create_study(storage="sqlite:///optunaRLCRstudy.db", study_name=study_name, direction='maximize')

study.optimize(objective, n_trials=5)

print(f"Meilleur score: {study.best_value}")
print(f"Meilleur hyperparameters: {study.best_params}")
# Out:
# [I 2023-03-28 11:28:17,083] A new study created in RDB with name: study_200k_seed42
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1129..1416 -> 287-tiles track
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1048..1318 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1157..1451 -> 294-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1037..1307 -> 270-tiles track
# Track generation: 1011..1271 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1059..1328 -> 269-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1355..1697 -> 342-tiles track
# Track generation: 1131..1421 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1130..1417 -> 287-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1071..1352 -> 281-tiles track
# Track generation: 1042..1311 -> 269-tiles track
# Track generation: 1401..1755 -> 354-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1270..1592 -> 322-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1129..1424 -> 295-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1030..1295 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1118..1401 -> 283-tiles track
# Track generation: 1313..1645 -> 332-tiles track
# Track generation: 1193..1494 -> 301-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1034..1301 -> 267-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1003..1266 -> 263-tiles track
# Track generation: 1219..1534 -> 315-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1004..1261 -> 257-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1253..1570 -> 317-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1303..1633 -> 330-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1167..1473 -> 306-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1093..1371 -> 278-tiles track
# Track generation: 1372..1719 -> 347-tiles track
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1205..1518 -> 313-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1325..1660 -> 335-tiles track
# Track generation: 1285..1611 -> 326-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1103..1389 -> 286-tiles track
# Track generation: 1146..1435 -> 289-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1011..1273 -> 262-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1154..1449 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1165..1460 -> 295-tiles track
# Track generation: 1269..1597 -> 328-tiles track
# Track generation: 995..1248 -> 253-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1232..1552 -> 320-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 978..1232 -> 254-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 1185..1485 -> 300-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1400..1754 -> 354-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 994..1254 -> 260-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# Track generation: 1127..1414 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1242..1556 -> 314-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# Track generation: 1138..1435 -> 297-tiles track
# Track generation: 1089..1371 -> 282-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1092..1371 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# Track generation: 1157..1450 -> 293-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1099..1383 -> 284-tiles track
# Track generation: 1293..1620 -> 327-tiles track
# Track generation: 1297..1625 -> 328-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 940..1183 -> 243-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1250..1566 -> 316-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1226..1536 -> 310-tiles track
# Track generation: 1238..1552 -> 314-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1072..1343 -> 271-tiles track
# Track generation: 1027..1290 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1085..1361 -> 276-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1094..1374 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1332..1669 -> 337-tiles track
# Track generation: 1183..1485 -> 302-tiles track
# Track generation: 1198..1502 -> 304-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1111..1399 -> 288-tiles track
# Track generation: 1173..1470 -> 297-tiles track
# Track generation: 1005..1267 -> 262-tiles track
# Track generation: 1378..1726 -> 348-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1204..1517 -> 313-tiles track
# Track generation: 1237..1559 -> 322-tiles track
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1092..1375 -> 283-tiles track
# Track generation: 1106..1391 -> 285-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1080..1363 -> 283-tiles track
# Track generation: 1131..1417 -> 286-tiles track
# Track generation: 1156..1454 -> 298-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1391..1750 -> 359-tiles track
# Track generation: 1324..1659 -> 335-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1130..1416 -> 286-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1047..1314 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1174..1471 -> 297-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1127..1412 -> 285-tiles track
# Track generation: 1267..1596 -> 329-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1090..1372 -> 282-tiles track
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1052..1324 -> 272-tiles track
# Track generation: 1109..1390 -> 281-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1058..1327 -> 269-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1169..1465 -> 296-tiles track
# Track generation: 1091..1376 -> 285-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1075..1347 -> 272-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1032..1294 -> 262-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1279..1603 -> 324-tiles track
# Track generation: 1009..1268 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1114..1402 -> 288-tiles track
# Track generation: 1031..1293 -> 262-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1082..1356 -> 274-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1126..1412 -> 286-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 988..1239 -> 251-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# /Users/robinfournier/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:278: UserWarning: Path 'models/study_200k_seed42' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# Track generation: 899..1133 -> 234-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1039..1305 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# [I 2023-03-28 12:03:32,282] Trial 0 finished with value: 764.4983791157604 and parameters: {'learning_rate': 0.0004404439563695323, 'gamma': 0.9391774113519196, 'clip_range': 0.141118008074816, 'ent_coef': 0.0005216509661898132}. Best is trial 0 with value: 764.4983791157604.
# Track generation: 1229..1546 -> 317-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1129..1416 -> 287-tiles track
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1048..1318 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1157..1451 -> 294-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1037..1307 -> 270-tiles track
# Track generation: 1011..1271 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1059..1328 -> 269-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1355..1697 -> 342-tiles track
# Track generation: 1131..1421 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1130..1417 -> 287-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1071..1352 -> 281-tiles track
# Track generation: 1042..1311 -> 269-tiles track
# Track generation: 1401..1755 -> 354-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1270..1592 -> 322-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1129..1424 -> 295-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1030..1295 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1118..1401 -> 283-tiles track
# Track generation: 1313..1645 -> 332-tiles track
# Track generation: 1193..1494 -> 301-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1034..1301 -> 267-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1003..1266 -> 263-tiles track
# Track generation: 1219..1534 -> 315-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1004..1261 -> 257-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1253..1570 -> 317-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1303..1633 -> 330-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1167..1473 -> 306-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1093..1371 -> 278-tiles track
# Track generation: 1372..1719 -> 347-tiles track
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1205..1518 -> 313-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1325..1660 -> 335-tiles track
# Track generation: 1285..1611 -> 326-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1103..1389 -> 286-tiles track
# Track generation: 1146..1435 -> 289-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1011..1273 -> 262-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1154..1449 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1165..1460 -> 295-tiles track
# Track generation: 1269..1597 -> 328-tiles track
# Track generation: 995..1248 -> 253-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1232..1552 -> 320-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 978..1232 -> 254-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 1185..1485 -> 300-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1400..1754 -> 354-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 994..1254 -> 260-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# Track generation: 1127..1414 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1242..1556 -> 314-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# Track generation: 1138..1435 -> 297-tiles track
# Track generation: 1089..1371 -> 282-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1092..1371 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# Track generation: 1157..1450 -> 293-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1099..1383 -> 284-tiles track
# Track generation: 1293..1620 -> 327-tiles track
# Track generation: 1297..1625 -> 328-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 940..1183 -> 243-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1250..1566 -> 316-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1226..1536 -> 310-tiles track
# Track generation: 1238..1552 -> 314-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1072..1343 -> 271-tiles track
# Track generation: 1027..1290 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1085..1361 -> 276-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1094..1374 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1332..1669 -> 337-tiles track
# Track generation: 1183..1485 -> 302-tiles track
# Track generation: 1198..1502 -> 304-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1111..1399 -> 288-tiles track
# Track generation: 1173..1470 -> 297-tiles track
# Track generation: 1005..1267 -> 262-tiles track
# Track generation: 1378..1726 -> 348-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1204..1517 -> 313-tiles track
# Track generation: 1237..1559 -> 322-tiles track
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1092..1375 -> 283-tiles track
# Track generation: 1106..1391 -> 285-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1080..1363 -> 283-tiles track
# Track generation: 1131..1417 -> 286-tiles track
# Track generation: 1156..1454 -> 298-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1391..1750 -> 359-tiles track
# Track generation: 1324..1659 -> 335-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1130..1416 -> 286-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1047..1314 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1174..1471 -> 297-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1127..1412 -> 285-tiles track
# Track generation: 1267..1596 -> 329-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1090..1372 -> 282-tiles track
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1052..1324 -> 272-tiles track
# Track generation: 1109..1390 -> 281-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1058..1327 -> 269-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1169..1465 -> 296-tiles track
# Track generation: 1091..1376 -> 285-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1075..1347 -> 272-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1032..1294 -> 262-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1279..1603 -> 324-tiles track
# Track generation: 1009..1268 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1114..1402 -> 288-tiles track
# Track generation: 1031..1293 -> 262-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1082..1356 -> 274-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1126..1412 -> 286-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 988..1239 -> 251-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 899..1133 -> 234-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1039..1305 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# [I 2023-03-28 12:37:30,406] Trial 1 finished with value: -92.64145351499319 and parameters: {'learning_rate': 0.006833748774518209, 'gamma': 0.96803210963415, 'clip_range': 0.14331628805385008, 'ent_coef': 0.0005407070298176535}. Best is trial 0 with value: 764.4983791157604.
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1129..1416 -> 287-tiles track
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1048..1318 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1157..1451 -> 294-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1037..1307 -> 270-tiles track
# Track generation: 1011..1271 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1059..1328 -> 269-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1355..1697 -> 342-tiles track
# Track generation: 1131..1421 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1130..1417 -> 287-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1071..1352 -> 281-tiles track
# Track generation: 1042..1311 -> 269-tiles track
# Track generation: 1401..1755 -> 354-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1270..1592 -> 322-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1129..1424 -> 295-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1030..1295 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1118..1401 -> 283-tiles track
# Track generation: 1313..1645 -> 332-tiles track
# Track generation: 1193..1494 -> 301-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1034..1301 -> 267-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1003..1266 -> 263-tiles track
# Track generation: 1219..1534 -> 315-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1004..1261 -> 257-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1253..1570 -> 317-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1303..1633 -> 330-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1167..1473 -> 306-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1093..1371 -> 278-tiles track
# Track generation: 1372..1719 -> 347-tiles track
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1205..1518 -> 313-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1325..1660 -> 335-tiles track
# Track generation: 1285..1611 -> 326-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1103..1389 -> 286-tiles track
# Track generation: 1146..1435 -> 289-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1011..1273 -> 262-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1154..1449 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1165..1460 -> 295-tiles track
# Track generation: 1269..1597 -> 328-tiles track
# Track generation: 995..1248 -> 253-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1232..1552 -> 320-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 978..1232 -> 254-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 1185..1485 -> 300-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1400..1754 -> 354-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 994..1254 -> 260-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# Track generation: 1127..1414 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1242..1556 -> 314-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# Track generation: 1138..1435 -> 297-tiles track
# Track generation: 1089..1371 -> 282-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1092..1371 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# Track generation: 1157..1450 -> 293-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1099..1383 -> 284-tiles track
# Track generation: 1293..1620 -> 327-tiles track
# Track generation: 1297..1625 -> 328-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 940..1183 -> 243-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1250..1566 -> 316-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1226..1536 -> 310-tiles track
# Track generation: 1238..1552 -> 314-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1072..1343 -> 271-tiles track
# Track generation: 1027..1290 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1085..1361 -> 276-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1094..1374 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1332..1669 -> 337-tiles track
# Track generation: 1183..1485 -> 302-tiles track
# Track generation: 1198..1502 -> 304-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1111..1399 -> 288-tiles track
# Track generation: 1173..1470 -> 297-tiles track
# Track generation: 1005..1267 -> 262-tiles track
# Track generation: 1378..1726 -> 348-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1204..1517 -> 313-tiles track
# Track generation: 1237..1559 -> 322-tiles track
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1092..1375 -> 283-tiles track
# Track generation: 1106..1391 -> 285-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1080..1363 -> 283-tiles track
# Track generation: 1131..1417 -> 286-tiles track
# Track generation: 1156..1454 -> 298-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1391..1750 -> 359-tiles track
# Track generation: 1324..1659 -> 335-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1130..1416 -> 286-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1047..1314 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1174..1471 -> 297-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1127..1412 -> 285-tiles track
# Track generation: 1267..1596 -> 329-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1090..1372 -> 282-tiles track
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1052..1324 -> 272-tiles track
# Track generation: 1109..1390 -> 281-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1058..1327 -> 269-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1169..1465 -> 296-tiles track
# Track generation: 1091..1376 -> 285-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1075..1347 -> 272-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1032..1294 -> 262-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1279..1603 -> 324-tiles track
# Track generation: 1009..1268 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1114..1402 -> 288-tiles track
# Track generation: 1031..1293 -> 262-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1082..1356 -> 274-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1126..1412 -> 286-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 988..1239 -> 251-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 899..1133 -> 234-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1039..1305 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1229..1546 -> 317-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# [I 2023-03-28 13:11:39,404] Trial 2 finished with value: -80.92981071025133 and parameters: {'learning_rate': 0.006383973566712401, 'gamma': 0.9624859458903102, 'clip_range': 0.2763684851066367, 'ent_coef': 0.0005370609394924749}. Best is trial 0 with value: 764.4983791157604.
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1129..1416 -> 287-tiles track
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1048..1318 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1157..1451 -> 294-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1037..1307 -> 270-tiles track
# Track generation: 1011..1271 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1059..1328 -> 269-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1355..1697 -> 342-tiles track
# Track generation: 1131..1421 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1130..1417 -> 287-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1071..1352 -> 281-tiles track
# Track generation: 1042..1311 -> 269-tiles track
# Track generation: 1401..1755 -> 354-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1270..1592 -> 322-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1129..1424 -> 295-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1030..1295 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1118..1401 -> 283-tiles track
# Track generation: 1313..1645 -> 332-tiles track
# Track generation: 1193..1494 -> 301-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1034..1301 -> 267-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1003..1266 -> 263-tiles track
# Track generation: 1219..1534 -> 315-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1004..1261 -> 257-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1253..1570 -> 317-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1303..1633 -> 330-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1167..1473 -> 306-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1093..1371 -> 278-tiles track
# Track generation: 1372..1719 -> 347-tiles track
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1205..1518 -> 313-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1325..1660 -> 335-tiles track
# Track generation: 1285..1611 -> 326-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1103..1389 -> 286-tiles track
# Track generation: 1146..1435 -> 289-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1011..1273 -> 262-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1154..1449 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1165..1460 -> 295-tiles track
# Track generation: 1269..1597 -> 328-tiles track
# Track generation: 995..1248 -> 253-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1232..1552 -> 320-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 978..1232 -> 254-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 1185..1485 -> 300-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1400..1754 -> 354-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 994..1254 -> 260-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# Track generation: 1127..1414 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1242..1556 -> 314-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# Track generation: 1138..1435 -> 297-tiles track
# Track generation: 1089..1371 -> 282-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1092..1371 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# Track generation: 1157..1450 -> 293-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1099..1383 -> 284-tiles track
# Track generation: 1293..1620 -> 327-tiles track
# Track generation: 1297..1625 -> 328-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 940..1183 -> 243-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1250..1566 -> 316-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1226..1536 -> 310-tiles track
# Track generation: 1238..1552 -> 314-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1072..1343 -> 271-tiles track
# Track generation: 1027..1290 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1085..1361 -> 276-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1094..1374 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1332..1669 -> 337-tiles track
# Track generation: 1183..1485 -> 302-tiles track
# Track generation: 1198..1502 -> 304-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1111..1399 -> 288-tiles track
# Track generation: 1173..1470 -> 297-tiles track
# Track generation: 1005..1267 -> 262-tiles track
# Track generation: 1378..1726 -> 348-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1204..1517 -> 313-tiles track
# Track generation: 1237..1559 -> 322-tiles track
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1092..1375 -> 283-tiles track
# Track generation: 1106..1391 -> 285-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1080..1363 -> 283-tiles track
# Track generation: 1131..1417 -> 286-tiles track
# Track generation: 1156..1454 -> 298-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1391..1750 -> 359-tiles track
# Track generation: 1324..1659 -> 335-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1130..1416 -> 286-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1047..1314 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1174..1471 -> 297-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1127..1412 -> 285-tiles track
# Track generation: 1267..1596 -> 329-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1090..1372 -> 282-tiles track
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1052..1324 -> 272-tiles track
# Track generation: 1109..1390 -> 281-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1058..1327 -> 269-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1169..1465 -> 296-tiles track
# Track generation: 1091..1376 -> 285-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1075..1347 -> 272-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1032..1294 -> 262-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1279..1603 -> 324-tiles track
# Track generation: 1009..1268 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1114..1402 -> 288-tiles track
# Track generation: 1031..1293 -> 262-tiles track
# Track generation: 1223..1533 -> 310-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1082..1356 -> 274-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1126..1412 -> 286-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 988..1239 -> 251-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 899..1133 -> 234-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1039..1305 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1229..1546 -> 317-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1070..1341 -> 271-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# [I 2023-03-28 13:45:57,131] Trial 3 finished with value: -86.63355255872011 and parameters: {'learning_rate': 0.009811487641228668, 'gamma': 0.9434657976600677, 'clip_range': 0.1943594733142664, 'ent_coef': 0.0008595743572266645}. Best is trial 0 with value: 764.4983791157604.
# Track generation: 1249..1564 -> 315-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1129..1416 -> 287-tiles track
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1048..1318 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1157..1451 -> 294-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1037..1307 -> 270-tiles track
# Track generation: 1011..1271 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1059..1328 -> 269-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1355..1697 -> 342-tiles track
# Track generation: 1131..1421 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1130..1417 -> 287-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1074..1347 -> 273-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1071..1352 -> 281-tiles track
# Track generation: 1042..1311 -> 269-tiles track
# Track generation: 1401..1755 -> 354-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1270..1592 -> 322-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1053..1320 -> 267-tiles track
# Track generation: 1129..1424 -> 295-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1030..1295 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1118..1401 -> 283-tiles track
# Track generation: 1313..1645 -> 332-tiles track
# Track generation: 1193..1494 -> 301-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1034..1301 -> 267-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1003..1266 -> 263-tiles track
# Track generation: 1219..1534 -> 315-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1004..1261 -> 257-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1253..1570 -> 317-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1303..1633 -> 330-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1167..1473 -> 306-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1093..1371 -> 278-tiles track
# Track generation: 1372..1719 -> 347-tiles track
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1205..1518 -> 313-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1325..1660 -> 335-tiles track
# Track generation: 1285..1611 -> 326-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1103..1389 -> 286-tiles track
# Track generation: 1146..1435 -> 289-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1011..1273 -> 262-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1154..1449 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1165..1460 -> 295-tiles track
# Track generation: 1269..1597 -> 328-tiles track
# Track generation: 995..1248 -> 253-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1232..1552 -> 320-tiles track
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 978..1232 -> 254-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 1185..1485 -> 300-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1400..1754 -> 354-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# Track generation: 994..1254 -> 260-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# Track generation: 1127..1414 -> 287-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1242..1556 -> 314-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# Track generation: 1138..1435 -> 297-tiles track
# Track generation: 1089..1371 -> 282-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1092..1371 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# Track generation: 1157..1450 -> 293-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1099..1383 -> 284-tiles track
# Track generation: 1293..1620 -> 327-tiles track
# Track generation: 1297..1625 -> 328-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 940..1183 -> 243-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1250..1566 -> 316-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1226..1536 -> 310-tiles track
# Track generation: 1238..1552 -> 314-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1072..1343 -> 271-tiles track
# Track generation: 1027..1290 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1085..1361 -> 276-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1094..1374 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1332..1669 -> 337-tiles track
# Track generation: 1183..1485 -> 302-tiles track
# Track generation: 1198..1502 -> 304-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1248..1564 -> 316-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1111..1399 -> 288-tiles track
# Track generation: 1173..1470 -> 297-tiles track
# Track generation: 1005..1267 -> 262-tiles track
# Track generation: 1378..1726 -> 348-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1204..1517 -> 313-tiles track
# Track generation: 1237..1559 -> 322-tiles track
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1092..1375 -> 283-tiles track
# Track generation: 1106..1391 -> 285-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1080..1363 -> 283-tiles track
# Track generation: 1131..1417 -> 286-tiles track
# Track generation: 1156..1454 -> 298-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1391..1750 -> 359-tiles track
# Track generation: 1324..1659 -> 335-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1130..1416 -> 286-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1047..1314 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1174..1471 -> 297-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1127..1412 -> 285-tiles track
# Track generation: 1267..1596 -> 329-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1075..1348 -> 273-tiles track

# %% [markdown]
# Loading best model to test

# %%
load_model_path = f'models/study_200k_seed42/PPO_0.0004404439563695323_0.9391774113519196__0.141118008074816_0.0005216509661898132__model'
model = PPO.load(load_model_path, env=env)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, render=True)
print('Récompense moyenne :', mean_reward, '||| Écart type :', std_reward)

# %% [markdown]
# Creation d'un model base à 1M de timesteps

# %%
environment_name = 'CarRacing-v0'
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

model = PPO("CnnPolicy", env, verbose=1, device='mps')

timesteps = 1000000
model.learn(total_timesteps=timesteps)

model_path = f'models/PPO_1M_base__model'
model.save(model_path)

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, render=True)
print('Récompense moyenne :', mean_reward, '||| Écart type :', std_reward)
# Out:
# Using mps device
# Wrapping the env in a VecTransposeImage.
# Track generation: 1013..1275 -> 262-tiles track
# Track generation: 931..1168 -> 237-tiles track
# Track generation: 1101..1386 -> 285-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 158  |
# |    iterations      | 1    |
# |    time_elapsed    | 12   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1191..1501 -> 310-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008287225 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.006       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.265       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.996       |
# |    value_loss           | 0.906       |
# -----------------------------------------
# Track generation: 1122..1413 -> 291-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 3           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009550018 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.215       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00972    |
# |    std                  | 0.987       |
# |    value_loss           | 0.652       |
# -----------------------------------------
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1201..1506 -> 305-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 4           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009021802 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.0901      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0489      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00967    |
# |    std                  | 0.982       |
# |    value_loss           | 0.376       |
# -----------------------------------------
# Track generation: 1063..1334 -> 271-tiles track
# Track generation: 1047..1319 -> 272-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 5           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015031356 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.977       |
# |    value_loss           | 0.426       |
# -----------------------------------------
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1085..1359 -> 274-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 6           |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014589302 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0807      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.963       |
# |    value_loss           | 0.265       |
# -----------------------------------------
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1085..1360 -> 275-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 7           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013766224 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.953       |
# |    value_loss           | 0.316       |
# -----------------------------------------
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1213..1528 -> 315-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 8           |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014890457 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0399      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.945       |
# |    value_loss           | 0.307       |
# -----------------------------------------
# Track generation: 1269..1590 -> 321-tiles track
# Track generation: 1126..1421 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 9           |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013252694 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0482      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.932       |
# |    value_loss           | 0.2         |
# -----------------------------------------
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 10          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024006821 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0696      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0228     |
# |    std                  | 0.929       |
# |    value_loss           | 0.194       |
# -----------------------------------------
# Track generation: 1197..1500 -> 303-tiles track
# Track generation: 1066..1336 -> 270-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 11          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019657122 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0218      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.925       |
# |    value_loss           | 0.189       |
# -----------------------------------------
# Track generation: 1118..1402 -> 284-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 12          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022249807 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000765    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.023      |
# |    std                  | 0.918       |
# |    value_loss           | 0.133       |
# -----------------------------------------
# Track generation: 980..1235 -> 255-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 13          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018887244 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0314      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.908       |
# |    value_loss           | 0.155       |
# -----------------------------------------
# Track generation: 1137..1425 -> 288-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 14          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019049024 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.9         |
# |    value_loss           | 0.209       |
# -----------------------------------------
# Track generation: 1011..1268 -> 257-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 15          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020588417 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00404    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.889       |
# |    value_loss           | 0.0972      |
# -----------------------------------------
# Track generation: 1165..1466 -> 301-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 16          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018778067 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0174      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.885       |
# |    value_loss           | 0.127       |
# -----------------------------------------
# Track generation: 1270..1591 -> 321-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 17          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.026229179 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00263     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.874       |
# |    value_loss           | 0.128       |
# -----------------------------------------
# Track generation: 1120..1404 -> 284-tiles track
# Track generation: 1198..1502 -> 304-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 18         |
# |    time_elapsed         | 368        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02231685 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.82      |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0335     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0263    |
# |    std                  | 0.857      |
# |    value_loss           | 0.111      |
# ----------------------------------------
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1272..1597 -> 325-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 19          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019400222 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0267     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.851       |
# |    value_loss           | 0.119       |
# -----------------------------------------
# Track generation: 1217..1525 -> 308-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 20          |
# |    time_elapsed         | 410         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021000452 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0292     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.839       |
# |    value_loss           | 0.0915      |
# -----------------------------------------
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1058..1329 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1220..1529 -> 309-tiles track
# Track generation: 1045..1310 -> 265-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 21          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.020426504 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0354     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.831       |
# |    value_loss           | 0.0877      |
# -----------------------------------------
# Track generation: 989..1247 -> 258-tiles track
# Track generation: 1290..1617 -> 327-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 22          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031026686 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0372     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0293     |
# |    std                  | 0.819       |
# |    value_loss           | 0.0867      |
# -----------------------------------------
# Track generation: 1117..1410 -> 293-tiles track
# Track generation: 1113..1401 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 23          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025629528 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0131      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.812       |
# |    value_loss           | 0.113       |
# -----------------------------------------
# Track generation: 1272..1600 -> 328-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 24         |
# |    time_elapsed         | 493        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.04354273 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.62      |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0213    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0298    |
# |    std                  | 0.803      |
# |    value_loss           | 0.109      |
# ----------------------------------------
# Track generation: 1284..1609 -> 325-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 25         |
# |    time_elapsed         | 515        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.03333633 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.59      |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0299    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0285    |
# |    std                  | 0.8        |
# |    value_loss           | 0.0637     |
# ----------------------------------------
# Track generation: 1060..1329 -> 269-tiles track
# Track generation: 1067..1345 -> 278-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 26          |
# |    time_elapsed         | 535         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.038363732 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.57       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0263     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.79        |
# |    value_loss           | 0.0531      |
# -----------------------------------------
# Track generation: 1212..1519 -> 307-tiles track
# Track generation: 1101..1380 -> 279-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 27         |
# |    time_elapsed         | 556        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.03302677 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.52      |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0399    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0253    |
# |    std                  | 0.778      |
# |    value_loss           | 0.0921     |
# ----------------------------------------
# Track generation: 1175..1479 -> 304-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 28          |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.027330814 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.783       |
# |    value_loss           | 0.0771      |
# -----------------------------------------
# Track generation: 1089..1372 -> 283-tiles track
# Track generation: 1108..1389 -> 281-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 29          |
# |    time_elapsed         | 598         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.038264904 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00722    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.786       |
# |    value_loss           | 0.0732      |
# -----------------------------------------
# Track generation: 1175..1475 -> 300-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1047..1313 -> 266-tiles track
# Track generation: 987..1242 -> 255-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 30          |
# |    time_elapsed         | 619         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.034153022 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0077     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 0.782       |
# |    value_loss           | 0.112       |
# -----------------------------------------
# Track generation: 1027..1288 -> 261-tiles track
# Track generation: 1166..1462 -> 296-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 31          |
# |    time_elapsed         | 640         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.039586958 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.771       |
# |    value_loss           | 0.0781      |
# -----------------------------------------
# Track generation: 996..1260 -> 264-tiles track
# Track generation: 1147..1444 -> 297-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 32          |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.043503474 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0275     |
# |    std                  | 0.768       |
# |    value_loss           | 0.068       |
# -----------------------------------------
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1351..1693 -> 342-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 33          |
# |    time_elapsed         | 682         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.025021601 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0248     |
# |    std                  | 0.761       |
# |    value_loss           | 0.0384      |
# -----------------------------------------
# Track generation: 1126..1412 -> 286-tiles track
# Track generation: 1251..1568 -> 317-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 34         |
# |    time_elapsed         | 703        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.03997861 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0345    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0293    |
# |    std                  | 0.758      |
# |    value_loss           | 0.0263     |
# ----------------------------------------
# Track generation: 987..1241 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1381..1731 -> 350-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 35          |
# |    time_elapsed         | 724         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.028426215 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0404     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 0.754       |
# |    value_loss           | 0.0397      |
# -----------------------------------------
# Track generation: 1284..1609 -> 325-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 36         |
# |    time_elapsed         | 745        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.03465647 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.38      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0119    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0354    |
# |    std                  | 0.739      |
# |    value_loss           | 0.0312     |
# ----------------------------------------
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1266..1587 -> 321-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 37          |
# |    time_elapsed         | 766         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.046223156 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0406     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0272     |
# |    std                  | 0.735       |
# |    value_loss           | 0.0241      |
# -----------------------------------------
# Track generation: 1321..1654 -> 333-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 38          |
# |    time_elapsed         | 787         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.041222237 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.33       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0602     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0395     |
# |    std                  | 0.733       |
# |    value_loss           | 0.0345      |
# -----------------------------------------
# Track generation: 1051..1318 -> 267-tiles track
# Track generation: 1321..1659 -> 338-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 39          |
# |    time_elapsed         | 808         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.038456872 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0346     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0345     |
# |    std                  | 0.723       |
# |    value_loss           | 0.0858      |
# -----------------------------------------
# Track generation: 935..1173 -> 238-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 40         |
# |    time_elapsed         | 829        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.04988935 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.26      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0491    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0394    |
# |    std                  | 0.715      |
# |    value_loss           | 0.037      |
# ----------------------------------------
# Track generation: 1236..1549 -> 313-tiles track
# Track generation: 957..1203 -> 246-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1075..1347 -> 272-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 41         |
# |    time_elapsed         | 850        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.05128324 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0471    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0411    |
# |    std                  | 0.708      |
# |    value_loss           | 0.104      |
# ----------------------------------------
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1153..1445 -> 292-tiles track
# Track generation: 976..1233 -> 257-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 42          |
# |    time_elapsed         | 871         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.052361604 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0687     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0385     |
# |    std                  | 0.698       |
# |    value_loss           | 0.0731      |
# -----------------------------------------
# Track generation: 1250..1567 -> 317-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 43         |
# |    time_elapsed         | 892        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.08037813 |
# |    clip_fraction        | 0.357      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0531    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0472    |
# |    std                  | 0.689      |
# |    value_loss           | 0.0604     |
# ----------------------------------------
# Track generation: 1123..1415 -> 292-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 44          |
# |    time_elapsed         | 913         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.061995402 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.043      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0306     |
# |    std                  | 0.681       |
# |    value_loss           | 0.0727      |
# -----------------------------------------
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1208..1523 -> 315-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 45          |
# |    time_elapsed         | 934         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.056432832 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0431     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0376     |
# |    std                  | 0.68        |
# |    value_loss           | 0.0643      |
# -----------------------------------------
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 46          |
# |    time_elapsed         | 955         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.046519935 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0286     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0352     |
# |    std                  | 0.673       |
# |    value_loss           | 0.0335      |
# -----------------------------------------
# Track generation: 1489..1865 -> 376-tiles track
# Track generation: 1120..1404 -> 284-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 47         |
# |    time_elapsed         | 977        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.10884549 |
# |    clip_fraction        | 0.347      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.05      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0716    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0475    |
# |    std                  | 0.663      |
# |    value_loss           | 0.0765     |
# ----------------------------------------
# Track generation: 1082..1360 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1128..1421 -> 293-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 48         |
# |    time_elapsed         | 998        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.08009176 |
# |    clip_fraction        | 0.371      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.02      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0612    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0407    |
# |    std                  | 0.66       |
# |    value_loss           | 0.0546     |
# ----------------------------------------
# Track generation: 943..1190 -> 247-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 49         |
# |    time_elapsed         | 1019       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.07772593 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0343    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0464    |
# |    std                  | 0.658      |
# |    value_loss           | 0.151      |
# ----------------------------------------
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1195..1498 -> 303-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 50         |
# |    time_elapsed         | 1039       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.08191872 |
# |    clip_fraction        | 0.442      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | 0.843      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0308    |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0479    |
# |    std                  | 0.649      |
# |    value_loss           | 0.235      |
# ----------------------------------------
# Track generation: 1262..1591 -> 329-tiles track
# Track generation: 1273..1595 -> 322-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 51         |
# |    time_elapsed         | 1061       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.07803063 |
# |    clip_fraction        | 0.402      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.026     |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0444    |
# |    std                  | 0.639      |
# |    value_loss           | 0.221      |
# ----------------------------------------
# Track generation: 1032..1294 -> 262-tiles track
# Track generation: 1165..1470 -> 305-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 98        |
# |    iterations           | 52        |
# |    time_elapsed         | 1082      |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.0954234 |
# |    clip_fraction        | 0.458     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.9      |
# |    explained_variance   | 0.916     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0901   |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.0572   |
# |    std                  | 0.633     |
# |    value_loss           | 0.104     |
# ---------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1036..1305 -> 269-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 98       |
# |    iterations           | 53       |
# |    time_elapsed         | 1103     |
# |    total_timesteps      | 108544   |
# | train/                  |          |
# |    approx_kl            | 0.281249 |
# |    clip_fraction        | 0.443    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.86    |
# |    explained_variance   | 0.888    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.049   |
# |    n_updates            | 520      |
# |    policy_gradient_loss | -0.0483  |
# |    std                  | 0.624    |
# |    value_loss           | 0.149    |
# --------------------------------------
# Track generation: 1215..1523 -> 308-tiles track
# Track generation: 1263..1583 -> 320-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 98        |
# |    iterations           | 54        |
# |    time_elapsed         | 1124      |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 0.1003903 |
# |    clip_fraction        | 0.481     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.82     |
# |    explained_variance   | 0.911     |
# ...
# |    n_updates            | 4700      |
# |    policy_gradient_loss | 0.118     |
# |    std                  | 0.0287    |
# |    value_loss           | 0.157     |
# ---------------------------------------
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 929..1171 -> 242-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 472       |
# |    time_elapsed         | 9946      |
# |    total_timesteps      | 966656    |
# | train/                  |           |
# |    approx_kl            | 48.502083 |
# |    clip_fraction        | 0.915     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.5       |
# |    explained_variance   | 0.986     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.182     |
# |    n_updates            | 4710      |
# |    policy_gradient_loss | 0.129     |
# |    std                  | 0.0285    |
# |    value_loss           | 0.163     |
# ---------------------------------------
# Track generation: 1192..1494 -> 302-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 473       |
# |    time_elapsed         | 9967      |
# |    total_timesteps      | 968704    |
# | train/                  |           |
# |    approx_kl            | 158.92331 |
# |    clip_fraction        | 0.905     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.5       |
# |    explained_variance   | 0.976     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0978    |
# |    n_updates            | 4720      |
# |    policy_gradient_loss | 0.08      |
# |    std                  | 0.0287    |
# |    value_loss           | 0.195     |
# ---------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 474       |
# |    time_elapsed         | 9988      |
# |    total_timesteps      | 970752    |
# | train/                  |           |
# |    approx_kl            | 23.907097 |
# |    clip_fraction        | 0.917     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.48      |
# |    explained_variance   | 0.979     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.133     |
# |    n_updates            | 4730      |
# |    policy_gradient_loss | 0.12      |
# |    std                  | 0.0289    |
# |    value_loss           | 0.198     |
# ---------------------------------------
# Track generation: 1220..1529 -> 309-tiles track
# Track generation: 1319..1653 -> 334-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 475      |
# |    time_elapsed         | 10010    |
# |    total_timesteps      | 972800   |
# | train/                  |          |
# |    approx_kl            | 9.161223 |
# |    clip_fraction        | 0.901    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.45     |
# |    explained_variance   | 0.984    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.18     |
# |    n_updates            | 4740     |
# |    policy_gradient_loss | 0.17     |
# |    std                  | 0.0295   |
# |    value_loss           | 0.164    |
# --------------------------------------
# Track generation: 1324..1659 -> 335-tiles track
# Track generation: 1071..1343 -> 272-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 476       |
# |    time_elapsed         | 10031     |
# |    total_timesteps      | 974848    |
# | train/                  |           |
# |    approx_kl            | 15.849129 |
# |    clip_fraction        | 0.913     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.41      |
# |    explained_variance   | 0.981     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.158     |
# |    n_updates            | 4750      |
# |    policy_gradient_loss | 0.178     |
# |    std                  | 0.0297    |
# |    value_loss           | 0.145     |
# ---------------------------------------
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 1047..1314 -> 267-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 477       |
# |    time_elapsed         | 10053     |
# |    total_timesteps      | 976896    |
# | train/                  |           |
# |    approx_kl            | 40.687157 |
# |    clip_fraction        | 0.92      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.36      |
# |    explained_variance   | 0.978     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.196     |
# |    n_updates            | 4760      |
# |    policy_gradient_loss | 0.166     |
# |    std                  | 0.0303    |
# |    value_loss           | 0.179     |
# ---------------------------------------
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1253..1570 -> 317-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 478      |
# |    time_elapsed         | 10074    |
# |    total_timesteps      | 978944   |
# | train/                  |          |
# |    approx_kl            | 66.90727 |
# |    clip_fraction        | 0.926    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.33     |
# |    explained_variance   | 0.944    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.202    |
# |    n_updates            | 4770     |
# |    policy_gradient_loss | 0.148    |
# |    std                  | 0.0301   |
# |    value_loss           | 0.288    |
# --------------------------------------
# Track generation: 1206..1507 -> 301-tiles track
# Track generation: 1341..1680 -> 339-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 479      |
# |    time_elapsed         | 10095    |
# |    total_timesteps      | 980992   |
# | train/                  |          |
# |    approx_kl            | 30.32248 |
# |    clip_fraction        | 0.912    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.32     |
# |    explained_variance   | 0.974    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.175    |
# |    n_updates            | 4780     |
# |    policy_gradient_loss | 0.181    |
# |    std                  | 0.0306   |
# |    value_loss           | 0.238    |
# --------------------------------------
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1091..1372 -> 281-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 480      |
# |    time_elapsed         | 10117    |
# |    total_timesteps      | 983040   |
# | train/                  |          |
# |    approx_kl            | 59.7977  |
# |    clip_fraction        | 0.887    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.32     |
# |    explained_variance   | 0.98     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0158   |
# |    n_updates            | 4790     |
# |    policy_gradient_loss | 0.101    |
# |    std                  | 0.0303   |
# |    value_loss           | 0.168    |
# --------------------------------------
# Track generation: 1050..1317 -> 267-tiles track
# Track generation: 1167..1460 -> 293-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 481      |
# |    time_elapsed         | 10138    |
# |    total_timesteps      | 985088   |
# | train/                  |          |
# |    approx_kl            | 33.77465 |
# |    clip_fraction        | 0.882    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.34     |
# |    explained_variance   | 0.985    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.103    |
# |    n_updates            | 4800     |
# |    policy_gradient_loss | 0.0655   |
# |    std                  | 0.0302   |
# |    value_loss           | 0.135    |
# --------------------------------------
# Track generation: 1213..1526 -> 313-tiles track
# Track generation: 1096..1381 -> 285-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 482      |
# |    time_elapsed         | 10159    |
# |    total_timesteps      | 987136   |
# | train/                  |          |
# |    approx_kl            | 84.83389 |
# |    clip_fraction        | 0.909    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.35     |
# |    explained_variance   | 0.982    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0393   |
# |    n_updates            | 4810     |
# |    policy_gradient_loss | 0.0561   |
# |    std                  | 0.0299   |
# |    value_loss           | 0.139    |
# --------------------------------------
# Track generation: 1231..1552 -> 321-tiles track
# Track generation: 1185..1485 -> 300-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 483      |
# |    time_elapsed         | 10181    |
# |    total_timesteps      | 989184   |
# | train/                  |          |
# |    approx_kl            | 85.62523 |
# |    clip_fraction        | 0.903    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.41     |
# |    explained_variance   | 0.992    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0222  |
# |    n_updates            | 4820     |
# |    policy_gradient_loss | 0.00697  |
# |    std                  | 0.0293   |
# |    value_loss           | 0.094    |
# --------------------------------------
# Track generation: 1039..1303 -> 264-tiles track
# Track generation: 1117..1400 -> 283-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 484        |
# |    time_elapsed         | 10202      |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 121.609055 |
# |    clip_fraction        | 0.883      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 6.43       |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0119     |
# |    n_updates            | 4830       |
# |    policy_gradient_loss | 0.0609     |
# |    std                  | 0.0295     |
# |    value_loss           | 0.143      |
# ----------------------------------------
# Track generation: 1164..1459 -> 295-tiles track
# Track generation: 1295..1623 -> 328-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 485      |
# |    time_elapsed         | 10223    |
# |    total_timesteps      | 993280   |
# | train/                  |          |
# |    approx_kl            | 132.1185 |
# |    clip_fraction        | 0.89     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.43     |
# |    explained_variance   | 0.989    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0084  |
# |    n_updates            | 4840     |
# |    policy_gradient_loss | 0.0454   |
# |    std                  | 0.0294   |
# |    value_loss           | 0.17     |
# --------------------------------------
# Track generation: 1000..1259 -> 259-tiles track
# Track generation: 1078..1352 -> 274-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 486       |
# |    time_elapsed         | 10244     |
# |    total_timesteps      | 995328    |
# | train/                  |           |
# |    approx_kl            | 46.230484 |
# |    clip_fraction        | 0.908     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.44      |
# |    explained_variance   | 0.987     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.103     |
# |    n_updates            | 4850      |
# |    policy_gradient_loss | 0.117     |
# |    std                  | 0.0294    |
# |    value_loss           | 0.164     |
# ---------------------------------------
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1141..1430 -> 289-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 487      |
# |    time_elapsed         | 10265    |
# |    total_timesteps      | 997376   |
# | train/                  |          |
# |    approx_kl            | 61.68386 |
# |    clip_fraction        | 0.927    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.43     |
# |    explained_variance   | 0.98     |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0749   |
# |    n_updates            | 4860     |
# |    policy_gradient_loss | 0.131    |
# |    std                  | 0.0296   |
# |    value_loss           | 0.173    |
# --------------------------------------
# Track generation: 940..1186 -> 246-tiles track
# Track generation: 1052..1319 -> 267-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 97       |
# |    iterations           | 488      |
# |    time_elapsed         | 10287    |
# |    total_timesteps      | 999424   |
# | train/                  |          |
# |    approx_kl            | 80.1488  |
# |    clip_fraction        | 0.922    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.43     |
# |    explained_variance   | 0.988    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0786   |
# |    n_updates            | 4870     |
# |    policy_gradient_loss | 0.122    |
# |    std                  | 0.0296   |
# |    value_loss           | 0.111    |
# --------------------------------------
# Track generation: 1115..1402 -> 287-tiles track
# Track generation: 977..1232 -> 255-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 97        |
# |    iterations           | 489       |
# |    time_elapsed         | 10308     |
# |    total_timesteps      | 1001472   |
# | train/                  |           |
# |    approx_kl            | 28.736328 |
# |    clip_fraction        | 0.904     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.44      |
# |    explained_variance   | 0.982     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.122     |
# |    n_updates            | 4880      |
# |    policy_gradient_loss | 0.0743    |
# |    std                  | 0.0293    |
# |    value_loss           | 0.215     |
# ---------------------------------------
# Track generation: 1162..1460 -> 298-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1090..1373 -> 283-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1344..1684 -> 340-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# Récompense moyenne : -0.15621658116579057 ||| Écart type : 10.234504626519739

# %% [markdown]
# Creation d'un model à 500k timesteps avec les meilleurs hyperparametres trouvés par Optuna

# %%
environment_name = 'CarRacing-v0'
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

model = PPO("CnnPolicy", env, verbose=1, 
            clip_range=0.21404777037661815, ent_coef=0.00093977018380121, 
            gamma=0.9183776997781369, learning_rate=0.00039317898096148755, 
            device='mps')

timesteps = 500000
model.learn(total_timesteps=timesteps)

model_path = f'models/PPO_500k_best_optuna__model'
model.save(model_path)

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, render=True)
print('Récompense moyenne :', mean_reward, '||| Écart type :', std_reward)
# Out:
# Using mps device
# Wrapping the env in a VecTransposeImage.
# Track generation: 1107..1388 -> 281-tiles track
# 2023-03-27 15:48:19.824 Python[33733:5970049] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/y0/7mmq5kp12fq249dxyngjmwv80000gn/T/org.python.python.savedState
# Track generation: 1060..1329 -> 269-tiles track
# Track generation: 1211..1518 -> 307-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 126  |
# |    iterations      | 1    |
# |    time_elapsed    | 16   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1241..1555 -> 314-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 2           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008780808 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.0049     |
# |    learning_rate        | 0.000393    |
# |    loss                 | 0.111       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 1           |
# |    value_loss           | 0.428       |
# -----------------------------------------
# Track generation: 1059..1335 -> 276-tiles track
# Track generation: 1301..1630 -> 329-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 3           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013730111 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.0274      |
# |    learning_rate        | 0.000393    |
# |    loss                 | 0.036       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.991       |
# |    value_loss           | 0.263       |
# -----------------------------------------
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 4           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015632898 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.073       |
# |    learning_rate        | 0.000393    |
# |    loss                 | 0.0353      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.978       |
# |    value_loss           | 0.29        |
# -----------------------------------------
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1213..1520 -> 307-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 5           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016852733 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | -0.0797     |
# |    learning_rate        | 0.000393    |
# |    loss                 | 0.0782      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.977       |
# |    value_loss           | 0.279       |
# -----------------------------------------
# Track generation: 1280..1604 -> 324-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 6           |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.023189018 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.0475      |
# |    learning_rate        | 0.000393    |
# |    loss                 | 0.0335      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.956       |
# |    value_loss           | 0.23        |
# -----------------------------------------
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 7           |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023525802 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.000393    |
# |    loss                 | 0.0407      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 0.944       |
# |    value_loss           | 0.195       |
# -----------------------------------------
# Track generation: 1344..1684 -> 340-tiles track
# Track generation: 1234..1546 -> 312-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 8          |
# |    time_elapsed         | 168        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.03180758 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -4.06      |
# |    explained_variance   | -0.00869   |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.041     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.041     |
# |    std                  | 0.93       |
# |    value_loss           | 0.242      |
# ----------------------------------------
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1252..1572 -> 320-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1151..1448 -> 297-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 9           |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.042888146 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.026       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0101     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0382     |
# |    std                  | 0.922       |
# |    value_loss           | 0.174       |
# -----------------------------------------
# Track generation: 1178..1479 -> 301-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1205..1510 -> 305-tiles track
# Track generation: 1172..1470 -> 298-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 10          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.053460736 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0237     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0434     |
# |    std                  | 0.912       |
# |    value_loss           | 0.191       |
# -----------------------------------------
# Track generation: 1175..1482 -> 307-tiles track
# Track generation: 1151..1443 -> 292-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 11          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.044941105 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.056       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0398     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.037      |
# |    std                  | 0.899       |
# |    value_loss           | 0.115       |
# -----------------------------------------
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 12          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.052912377 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.000393    |
# |    loss                 | 0.0298      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0385     |
# |    std                  | 0.89        |
# |    value_loss           | 0.113       |
# -----------------------------------------
# Track generation: 1129..1416 -> 287-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 13          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.051124264 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0648     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0404     |
# |    std                  | 0.881       |
# |    value_loss           | 0.0713      |
# -----------------------------------------
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1048..1314 -> 266-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 14         |
# |    time_elapsed         | 290        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.04518742 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -3.85      |
# |    explained_variance   | 0.368      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0449    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0332    |
# |    std                  | 0.869      |
# |    value_loss           | 0.0927     |
# ----------------------------------------
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1118..1402 -> 284-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 15         |
# |    time_elapsed         | 311        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.04653252 |
# |    clip_fraction        | 0.311      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -3.82      |
# |    explained_variance   | 0.383      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0395    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0391    |
# |    std                  | 0.863      |
# |    value_loss           | 0.104      |
# ----------------------------------------
# Track generation: 973..1227 -> 254-tiles track
# Track generation: 1202..1506 -> 304-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 16          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.052003734 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0243     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0404     |
# |    std                  | 0.858       |
# |    value_loss           | 0.0882      |
# -----------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 17          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.052764602 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0087     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0408     |
# |    std                  | 0.853       |
# |    value_loss           | 0.181       |
# -----------------------------------------
# Track generation: 1030..1299 -> 269-tiles track
# Track generation: 1116..1398 -> 282-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 18          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.084952906 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0276     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0469     |
# |    std                  | 0.835       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 19         |
# |    time_elapsed         | 392        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.09230095 |
# |    clip_fraction        | 0.369      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -3.67      |
# |    explained_variance   | 0.237      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0797    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0432    |
# |    std                  | 0.821      |
# |    value_loss           | 0.0756     |
# ----------------------------------------
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1169..1465 -> 296-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 20          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.059484527 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0423     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.04       |
# |    std                  | 0.809       |
# |    value_loss           | 0.0532      |
# -----------------------------------------
# Track generation: 1303..1633 -> 330-tiles track
# Track generation: 945..1189 -> 244-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 962..1209 -> 247-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 21         |
# |    time_elapsed         | 434        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.06117846 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.546      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0499    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0406    |
# |    std                  | 0.795      |
# |    value_loss           | 0.0554     |
# ----------------------------------------
# Track generation: 1052..1319 -> 267-tiles track
# Track generation: 1095..1373 -> 278-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 22         |
# |    time_elapsed         | 454        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.07245565 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | 0.569      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0849    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0489    |
# |    std                  | 0.795      |
# |    value_loss           | 0.0415     |
# ----------------------------------------
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1155..1454 -> 299-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 23         |
# |    time_elapsed         | 474        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.07272753 |
# |    clip_fraction        | 0.354      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -3.53      |
# |    explained_variance   | 0.562      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0687    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0367    |
# |    std                  | 0.785      |
# |    value_loss           | 0.0485     |
# ----------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 24          |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.062407684 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0728     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0342     |
# |    std                  | 0.777       |
# |    value_loss           | 0.0447      |
# -----------------------------------------
# Track generation: 1025..1289 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 1203..1508 -> 305-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 25          |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.077274166 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0624     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.038      |
# |    std                  | 0.77        |
# |    value_loss           | 0.032       |
# -----------------------------------------
# Track generation: 1272..1594 -> 322-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 26          |
# |    time_elapsed         | 535         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.115513206 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0785     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0569     |
# |    std                  | 0.749       |
# |    value_loss           | 0.0633      |
# -----------------------------------------
# Track generation: 1068..1343 -> 275-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 27          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.098724544 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.06       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0476     |
# |    std                  | 0.737       |
# |    value_loss           | 0.0546      |
# -----------------------------------------
# Track generation: 1143..1433 -> 290-tiles track
# Track generation: 1267..1588 -> 321-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 28          |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.097019255 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0504     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0378     |
# |    std                  | 0.723       |
# |    value_loss           | 0.0428      |
# -----------------------------------------
# Track generation: 1182..1485 -> 303-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 29          |
# |    time_elapsed         | 595         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.104008004 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0613     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0553     |
# |    std                  | 0.702       |
# |    value_loss           | 0.0502      |
# -----------------------------------------
# Track generation: 1143..1442 -> 299-tiles track
# Track generation: 1139..1426 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 30          |
# |    time_elapsed         | 616         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.109576136 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0432     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0401     |
# |    std                  | 0.697       |
# |    value_loss           | 0.0297      |
# -----------------------------------------
# Track generation: 1263..1583 -> 320-tiles track
# Track generation: 1055..1329 -> 274-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 31          |
# |    time_elapsed         | 636         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.095948145 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.214       |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.000393    |
# |    loss                 | -0.0811     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0434     |
# |    std                  | 0.693       |
# |    value_loss           | 0.0624      |
# -----------------------------------------
# Track generation: 1211..1525 -> 314-tiles track
# Track generation: 1163..1468 -> 305-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 32         |
# |    time_elapsed         | 656        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.18175337 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -3.11      |
# |    explained_variance   | 0.473      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0804    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.053     |
# |    std                  | 0.674      |
# |    value_loss           | 0.126      |
# ----------------------------------------
# Track generation: 1264..1584 -> 320-tiles track
# Track generation: 1238..1551 -> 313-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 99        |
# |    iterations           | 33        |
# |    time_elapsed         | 677       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.1303554 |
# |    clip_fraction        | 0.437     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | -3.03     |
# |    explained_variance   | 0.534     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0679   |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.0572   |
# |    std                  | 0.658     |
# |    value_loss           | 0.13      |
# ---------------------------------------
# Track generation: 982..1231 -> 249-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 34         |
# |    time_elapsed         | 697        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.17815164 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.95      |
# |    explained_variance   | 0.494      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0673    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0589    |
# |    std                  | 0.64       |
# |    value_loss           | 0.0765     |
# ----------------------------------------
# Track generation: 1203..1508 -> 305-tiles track
# Track generation: 984..1242 -> 258-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 35         |
# |    time_elapsed         | 718        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.18111461 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.86      |
# |    explained_variance   | 0.503      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0657    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0562    |
# |    std                  | 0.623      |
# |    value_loss           | 0.116      |
# ----------------------------------------
# Track generation: 1229..1540 -> 311-tiles track
# Track generation: 1174..1473 -> 299-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 36         |
# |    time_elapsed         | 737        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.17507209 |
# |    clip_fraction        | 0.489      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.79      |
# |    explained_variance   | 0.565      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0836    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0762    |
# |    std                  | 0.616      |
# |    value_loss           | 0.211      |
# ----------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1211..1518 -> 307-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 37         |
# |    time_elapsed         | 762        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.30316848 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.76      |
# |    explained_variance   | 0.536      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0938    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0717    |
# |    std                  | 0.602      |
# |    value_loss           | 0.149      |
# ----------------------------------------
# Track generation: 1141..1436 -> 295-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 38         |
# |    time_elapsed         | 784        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.24549174 |
# |    clip_fraction        | 0.57       |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 0.417      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0884    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0853    |
# |    std                  | 0.586      |
# |    value_loss           | 0.315      |
# ----------------------------------------
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 39         |
# |    time_elapsed         | 805        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.23945497 |
# |    clip_fraction        | 0.536      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.58      |
# |    explained_variance   | 0.544      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.107     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0782    |
# |    std                  | 0.568      |
# |    value_loss           | 0.109      |
# ----------------------------------------
# Track generation: 1012..1269 -> 257-tiles track
# Track generation: 1230..1543 -> 313-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 40         |
# |    time_elapsed         | 826        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.25848708 |
# |    clip_fraction        | 0.551      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.5       |
# |    explained_variance   | 0.629      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.115     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0747    |
# |    std                  | 0.553      |
# |    value_loss           | 0.125      |
# ----------------------------------------
# Track generation: 1132..1426 -> 294-tiles track
# Track generation: 1062..1337 -> 275-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 41         |
# |    time_elapsed         | 848        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.24401441 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.42      |
# |    explained_variance   | 0.589      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0839    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0849    |
# |    std                  | 0.54       |
# |    value_loss           | 0.196      |
# ----------------------------------------
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1118..1401 -> 283-tiles track
# Track generation: 987..1246 -> 259-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 42         |
# |    time_elapsed         | 869        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.23634706 |
# |    clip_fraction        | 0.553      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.34      |
# |    explained_variance   | 0.481      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0973    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0798    |
# |    std                  | 0.524      |
# |    value_loss           | 0.211      |
# ----------------------------------------
# Track generation: 1157..1454 -> 297-tiles track
# Track generation: 1271..1593 -> 322-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 98        |
# |    iterations           | 43        |
# |    time_elapsed         | 890       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.3659214 |
# |    clip_fraction        | 0.63      |
# |    clip_range           | 0.214     |
# |    entropy_loss         | -2.25     |
# |    explained_variance   | 0.662     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0625   |
# |    n_updates            | 420       |
# |    policy_gradient_loss | -0.0849   |
# |    std                  | 0.512     |
# |    value_loss           | 0.213     |
# ---------------------------------------
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 1307..1638 -> 331-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 44         |
# |    time_elapsed         | 912        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.25784206 |
# |    clip_fraction        | 0.575      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.19      |
# |    explained_variance   | 0.688      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0916    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0709    |
# |    std                  | 0.502      |
# |    value_loss           | 0.156      |
# ----------------------------------------
# Track generation: 1104..1390 -> 286-tiles track
# Track generation: 1207..1513 -> 306-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 45         |
# |    time_elapsed         | 933        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.53942686 |
# |    clip_fraction        | 0.638      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.13      |
# |    explained_variance   | 0.441      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.122     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.09      |
# |    std                  | 0.491      |
# |    value_loss           | 0.285      |
# ----------------------------------------
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1291..1618 -> 327-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 46         |
# |    time_elapsed         | 955        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.42274043 |
# |    clip_fraction        | 0.635      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -2.05      |
# |    explained_variance   | 0.549      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.124     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0855    |
# |    std                  | 0.476      |
# |    value_loss           | 0.235      |
# ----------------------------------------
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 47         |
# |    time_elapsed         | 976        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.35748476 |
# |    clip_fraction        | 0.624      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -1.97      |
# |    explained_variance   | 0.688      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0865    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0727    |
# |    std                  | 0.468      |
# |    value_loss           | 0.183      |
# ----------------------------------------
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 1131..1426 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 48         |
# |    time_elapsed         | 997        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.33592695 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -1.91      |
# |    explained_variance   | 0.606      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0778    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0681    |
# |    std                  | 0.452      |
# |    value_loss           | 0.101      |
# ----------------------------------------
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1007..1269 -> 262-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1073..1355 -> 282-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 49         |
# |    time_elapsed         | 1019       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.43099254 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -1.81      |
# |    explained_variance   | 0.577      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.109     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0821    |
# |    std                  | 0.439      |
# |    value_loss           | 0.134      |
# ----------------------------------------
# Track generation: 1260..1579 -> 319-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 98        |
# |    iterations           | 50        |
# |    time_elapsed         | 1040      |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.4661252 |
# |    clip_fraction        | 0.625     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | -1.71     |
# |    explained_variance   | 0.697     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.107    |
# |    n_updates            | 490       |
# |    policy_gradient_loss | -0.0736   |
# |    std                  | 0.425     |
# |    value_loss           | 0.18      |
# ---------------------------------------
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1107..1387 -> 280-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 51         |
# |    time_elapsed         | 1061       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.39493734 |
# |    clip_fraction        | 0.597      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | 0.705      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0913    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0772    |
# |    std                  | 0.416      |
# |    value_loss           | 0.174      |
# ----------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 52         |
# |    time_elapsed         | 1083       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.34605628 |
# |    clip_fraction        | 0.507      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.698      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0443    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.055     |
# |    std                  | 0.409      |
# |    value_loss           | 0.127      |
# ----------------------------------------
# Track generation: 1096..1374 -> 278-tiles track
# Track generation: 1093..1370 -> 277-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 53         |
# |    time_elapsed         | 1104       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.35520384 |
# |    clip_fraction        | 0.563      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -1.51      |
# |    explained_variance   | 0.737      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.065     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.065     |
# |    std                  | 0.402      |
# |    value_loss           | 0.151      |
# ----------------------------------------
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1023..1283 -> 260-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 54         |
# |    time_elapsed         | 1125       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.35122457 |
# |    clip_fraction        | 0.54       |
# |    clip_range           | 0.214      |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | 0.721      |
# |    learning_rate        | 0.000393   |
# ...
# |    clip_fraction        | 0.756    |
# |    clip_range           | 0.214    |
# |    entropy_loss         | 5.14     |
# |    explained_variance   | 0.955    |
# |    learning_rate        | 0.000393 |
# |    loss                 | -0.0466  |
# |    n_updates            | 1380     |
# |    policy_gradient_loss | -0.0135  |
# |    std                  | 0.0432   |
# |    value_loss           | 0.297    |
# --------------------------------------
# Track generation: 1275..1598 -> 323-tiles track
# Track generation: 1082..1362 -> 280-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 95        |
# |    iterations           | 140       |
# |    time_elapsed         | 3011      |
# |    total_timesteps      | 286720    |
# | train/                  |           |
# |    approx_kl            | 1.4992764 |
# |    clip_fraction        | 0.746     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.22      |
# |    explained_variance   | 0.968     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0151   |
# |    n_updates            | 1390      |
# |    policy_gradient_loss | -0.03     |
# |    std                  | 0.0421    |
# |    value_loss           | 0.303     |
# ---------------------------------------
# Track generation: 1240..1554 -> 314-tiles track
# Track generation: 1054..1321 -> 267-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 95        |
# |    iterations           | 141       |
# |    time_elapsed         | 3034      |
# |    total_timesteps      | 288768    |
# | train/                  |           |
# |    approx_kl            | 1.2480977 |
# |    clip_fraction        | 0.78      |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.29      |
# |    explained_variance   | 0.966     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0115   |
# |    n_updates            | 1400      |
# |    policy_gradient_loss | -0.022    |
# |    std                  | 0.0412    |
# |    value_loss           | 0.298     |
# ---------------------------------------
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1221..1530 -> 309-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 95        |
# |    iterations           | 142       |
# |    time_elapsed         | 3058      |
# |    total_timesteps      | 290816    |
# | train/                  |           |
# |    approx_kl            | 19.424673 |
# |    clip_fraction        | 0.837     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.34      |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.000393  |
# |    loss                 | 0.00611   |
# |    n_updates            | 1410      |
# |    policy_gradient_loss | -0.000556 |
# |    std                  | 0.0407    |
# |    value_loss           | 0.291     |
# ---------------------------------------
# Track generation: 1285..1609 -> 324-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1214..1529 -> 315-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 143        |
# |    time_elapsed         | 3081       |
# |    total_timesteps      | 292864     |
# | train/                  |            |
# |    approx_kl            | 0.81263804 |
# |    clip_fraction        | 0.726      |
# |    clip_range           | 0.214      |
# |    entropy_loss         | 5.39       |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.000393   |
# |    loss                 | -0.0447    |
# |    n_updates            | 1420       |
# |    policy_gradient_loss | -0.0121    |
# |    std                  | 0.0401     |
# |    value_loss           | 0.135      |
# ----------------------------------------
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1075..1348 -> 273-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 144       |
# |    time_elapsed         | 3106      |
# |    total_timesteps      | 294912    |
# | train/                  |           |
# |    approx_kl            | 1.1543125 |
# |    clip_fraction        | 0.771     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.44      |
# |    explained_variance   | 0.919     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0435   |
# |    n_updates            | 1430      |
# |    policy_gradient_loss | -0.0288   |
# |    std                  | 0.0392    |
# |    value_loss           | 0.234     |
# ---------------------------------------
# Track generation: 1073..1345 -> 272-tiles track
# Track generation: 1249..1566 -> 317-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 94       |
# |    iterations           | 145      |
# |    time_elapsed         | 3129     |
# |    total_timesteps      | 296960   |
# | train/                  |          |
# |    approx_kl            | 1.417496 |
# |    clip_fraction        | 0.777    |
# |    clip_range           | 0.214    |
# |    entropy_loss         | 5.52     |
# |    explained_variance   | 0.955    |
# |    learning_rate        | 0.000393 |
# |    loss                 | -0.0411  |
# |    n_updates            | 1440     |
# |    policy_gradient_loss | -0.0343  |
# |    std                  | 0.0382   |
# |    value_loss           | 0.328    |
# --------------------------------------
# Track generation: 1114..1397 -> 283-tiles track
# Track generation: 1230..1550 -> 320-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 94       |
# |    iterations           | 146      |
# |    time_elapsed         | 3150     |
# |    total_timesteps      | 299008   |
# | train/                  |          |
# |    approx_kl            | 1.169719 |
# |    clip_fraction        | 0.75     |
# |    clip_range           | 0.214    |
# |    entropy_loss         | 5.58     |
# |    explained_variance   | 0.965    |
# |    learning_rate        | 0.000393 |
# |    loss                 | -0.00703 |
# |    n_updates            | 1450     |
# |    policy_gradient_loss | -0.0158  |
# |    std                  | 0.0377   |
# |    value_loss           | 0.289    |
# --------------------------------------
# Track generation: 1293..1620 -> 327-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 147       |
# |    time_elapsed         | 3172      |
# |    total_timesteps      | 301056    |
# | train/                  |           |
# |    approx_kl            | 0.9907477 |
# |    clip_fraction        | 0.74      |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.6       |
# |    explained_variance   | 0.982     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0426   |
# |    n_updates            | 1460      |
# |    policy_gradient_loss | 0.00453   |
# |    std                  | 0.0375    |
# |    value_loss           | 0.146     |
# ---------------------------------------
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1075..1356 -> 281-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 148       |
# |    time_elapsed         | 3193      |
# |    total_timesteps      | 303104    |
# | train/                  |           |
# |    approx_kl            | 1.9478798 |
# |    clip_fraction        | 0.795     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.63      |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0503   |
# |    n_updates            | 1470      |
# |    policy_gradient_loss | -0.00483  |
# |    std                  | 0.0371    |
# |    value_loss           | 0.345     |
# ---------------------------------------
# Track generation: 972..1219 -> 247-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 149       |
# |    time_elapsed         | 3214      |
# |    total_timesteps      | 305152    |
# | train/                  |           |
# |    approx_kl            | 12.206732 |
# |    clip_fraction        | 0.861     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.69      |
# |    explained_variance   | 0.964     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0994   |
# |    n_updates            | 1480      |
# |    policy_gradient_loss | -0.0278   |
# |    std                  | 0.0361    |
# |    value_loss           | 0.206     |
# ---------------------------------------
# Track generation: 944..1189 -> 245-tiles track
# Track generation: 1153..1445 -> 292-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 94       |
# |    iterations           | 150      |
# |    time_elapsed         | 3235     |
# |    total_timesteps      | 307200   |
# | train/                  |          |
# |    approx_kl            | 5.114827 |
# |    clip_fraction        | 0.841    |
# |    clip_range           | 0.214    |
# |    entropy_loss         | 5.77     |
# |    explained_variance   | 0.969    |
# |    learning_rate        | 0.000393 |
# |    loss                 | -0.058   |
# |    n_updates            | 1490     |
# |    policy_gradient_loss | -0.0387  |
# |    std                  | 0.0353   |
# |    value_loss           | 0.378    |
# --------------------------------------
# Track generation: 1114..1405 -> 291-tiles track
# Track generation: 1004..1259 -> 255-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 151       |
# |    time_elapsed         | 3261      |
# |    total_timesteps      | 309248    |
# | train/                  |           |
# |    approx_kl            | 1.6159803 |
# |    clip_fraction        | 0.816     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.82      |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0489   |
# |    n_updates            | 1500      |
# |    policy_gradient_loss | -0.0117   |
# |    std                  | 0.0348    |
# |    value_loss           | 0.395     |
# ---------------------------------------
# Track generation: 1011..1268 -> 257-tiles track
# Track generation: 1185..1485 -> 300-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 152       |
# |    time_elapsed         | 3283      |
# |    total_timesteps      | 311296    |
# | train/                  |           |
# |    approx_kl            | 12.123745 |
# |    clip_fraction        | 0.895     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.87      |
# |    explained_variance   | 0.962     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0388   |
# |    n_updates            | 1510      |
# |    policy_gradient_loss | -0.0154   |
# |    std                  | 0.0341    |
# |    value_loss           | 0.382     |
# ---------------------------------------
# Track generation: 1168..1471 -> 303-tiles track
# Track generation: 1167..1479 -> 312-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 153       |
# |    time_elapsed         | 3305      |
# |    total_timesteps      | 313344    |
# | train/                  |           |
# |    approx_kl            | 3.6281202 |
# |    clip_fraction        | 0.836     |
# |    clip_range           | 0.214     |
# |    entropy_loss         | 5.92      |
# |    explained_variance   | 0.957     |
# |    learning_rate        | 0.000393  |
# |    loss                 | -0.0103   |
# |    n_updates            | 1520      |
# |    policy_gradient_loss | -0.027    |
# |    std                  | 0.0337    |
# |    value_loss           | 0.648     |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       5 model = PPO("CnnPolicy", env, verbose=1,
#       6             clip_range=0.21404777037661815, ent_coef=0.00093977018380121,
#       7             gamma=0.9183776997781369, learning_rate=0.00039317898096148755,
#       8             device='mps')
#      10 timesteps = 500000
# ---> 11 model.learn(total_timesteps=timesteps)
#      13 model_path = f'models/PPO_500k_best_optuna__model'
#      14 model.save(model_path)
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:318, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     308 def learn(
#     309     self: SelfPPO,
#     310     total_timesteps: int,
#    (...)
#     315     progress_bar: bool = False,
#     316 ) -> SelfPPO:
# --> 318     return super().learn(
#     319         total_timesteps=total_timesteps,
#     320         callback=callback,
#     321         log_interval=log_interval,
#     322         tb_log_name=tb_log_name,
#     323         reset_num_timesteps=reset_num_timesteps,
#     324         progress_bar=progress_bar,
#     325     )
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:269, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     266         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     267         self.logger.dump(step=self.num_timesteps)
# --> 269     self.train()
#     271 callback.on_training_end()
#     273 return self
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:199, in PPO.train(self)
#     197 approx_kl_divs = []
#     198 # Do a complete pass on the rollout buffer
# --> 199 for rollout_data in self.rollout_buffer.get(self.batch_size):
#     200     actions = rollout_data.actions
#     201     if isinstance(self.action_space, spaces.Discrete):
#     202         # Convert discrete action from float to long
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:474, in RolloutBuffer.get(self, batch_size)
#     472 start_idx = 0
#     473 while start_idx < self.buffer_size * self.n_envs:
# --> 474     yield self._get_samples(indices[start_idx : start_idx + batch_size])
#     475     start_idx += batch_size
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:486, in RolloutBuffer._get_samples(self, batch_inds, env)
#     477 def _get_samples(self, batch_inds: np.ndarray, env: Optional[VecNormalize] = None) -> RolloutBufferSamples:
#     478     data = (
#     479         self.observations[batch_inds],
#     480         self.actions[batch_inds],
#    (...)
#     484         self.returns[batch_inds].flatten(),
#     485     )
# --> 486     return RolloutBufferSamples(*tuple(map(self.to_torch, data)))
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:135, in BaseBuffer.to_torch(self, array, copy)
#     125 """
#     126 Convert a numpy array to a PyTorch tensor.
#     127 Note: it copies the data by default
#    (...)
#     132 :return:
#     133 """
#     134 if copy:
# --> 135     return th.tensor(array, device=self.device)
#     136 return th.as_tensor(array, device=self.device)
#
# KeyboardInterrupt:

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5, render=True)
print('Récompense moyenne :', mean_reward, '||| Écart type :', std_reward)
# Out:
# /Users/robinfournier/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1298..1636 -> 338-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1327..1663 -> 336-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1179..1486 -> 307-tiles track
# Récompense moyenne : 253.76776015609502 ||| Écart type : 132.00501921149507
