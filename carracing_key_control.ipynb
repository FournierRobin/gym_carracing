# %% [markdown]
# ## INITIALISATION

# %%
import gymnasium as gym
import pygame

env = gym.make("CarRacing-v2", continuous=False, render_mode="human")
obs_space = env.observation_space
action_space = env.action_space

# %% [markdown]
# ## HAND CONTROLS

# %%
env.reset()
while True:
    keys = pygame.key.get_pressed()

    if keys[pygame.K_UP]:
        action = 3  # gas
    elif keys[pygame.K_RIGHT]:
        action = 1  # steer left
    elif keys[pygame.K_DOWN]:
        action = 4  # brake
    elif keys[pygame.K_LEFT]:
        action = 2  # steer right
    else:
        action = 0  # do nothing

    env.step(action)
# Out:
# 2023-03-27 09:52:44.426 Python[35445:5683837] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/y0/7mmq5kp12fq249dxyngjmwv80000gn/T/org.python.python.savedState
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 16
#      13 else:
#      14     action = 0  # do nothing
# ---> 16 env.step(action)
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:51, in TimeLimit.step(self, action)
#      40 def step(self, action):
#      41     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      42
#      43     Args:
#    (...)
#      49
#      50     """
# ---> 51     observation, reward, terminated, truncated, info = self.env.step(action)
#      52     self._elapsed_steps += 1
#      54     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:38, in OrderEnforcing.step(self, action)
#      36 if not self._has_reset:
#      37     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 38 return self.env.step(action)
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/gymnasium/envs/box2d/car_racing.py:553, in CarRacing.step(self, action)
#     550 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     551 self.t += 1.0 / FPS
# --> 553 self.state = self._render("state_pixels")
#     555 step_reward = 0
#     556 terminated = False
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/gymnasium/envs/box2d/car_racing.py:647, in CarRacing._render(self, mode)
#     645     return self._create_image_array(self.surf, (VIDEO_W, VIDEO_H))
#     646 elif mode == "state_pixels":
# --> 647     return self._create_image_array(self.surf, (STATE_W, STATE_H))
#     648 else:
#     649     return self.isopen
#
# File ~/Desktop/YNOV/RL/car_racing/carracingenv/lib/python3.10/site-packages/gymnasium/envs/box2d/car_racing.py:778, in CarRacing._create_image_array(self, screen, size)
#     777 def _create_image_array(self, screen, size):
# --> 778     scaled_screen = pygame.transform.smoothscale(screen, size)
#     779     return np.transpose(
#     780         np.array(pygame.surfarray.pixels3d(scaled_screen)), axes=(1, 0, 2)
#     781     )
#
# KeyboardInterrupt:
